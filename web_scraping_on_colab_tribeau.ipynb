# %% [markdown]
# <a href="https://colab.research.google.com/github/usma11dia0/web_scraping_on_colab/blob/main/web_scraping_on_colab_tribeau.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%shell
# # Ubuntu no longer distributes chromium-browser outside of snap
# #
# # Proposed solution: https://askubuntu.com/questions/1204571/how-to-install-chromium-without-snap
#
# # Add debian buster
# cat > /etc/apt/sources.list.d/debian.list <<'EOF'
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-buster.gpg] http://deb.debian.org/debian buster main
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-buster-updates.gpg] http://deb.debian.org/debian buster-updates main
# deb [arch=amd64 signed-by=/usr/share/keyrings/debian-security-buster.gpg] http://deb.debian.org/debian-security buster/updates main
# EOF
#
# # Add keys
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys DCC9EFBF77E11517
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 648ACFD622F3D138
# apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 112695A0E562B32A
#
# apt-key export 77E11517 | gpg --dearmour -o /usr/share/keyrings/debian-buster.gpg
# apt-key export 22F3D138 | gpg --dearmour -o /usr/share/keyrings/debian-buster-updates.gpg
# apt-key export E562B32A | gpg --dearmour -o /usr/share/keyrings/debian-security-buster.gpg
#
# # Prefer debian repo for chromium* packages only
# # Note the double-blank lines between entries
# cat > /etc/apt/preferences.d/chromium.pref << 'EOF'
# Package: *
# Pin: release a=eoan
# Pin-Priority: 500
#
#
# Package: *
# Pin: origin "deb.debian.org"
# Pin-Priority: 300
#
#
# Package: chromium*
# Pin: origin "deb.debian.org"
# Pin-Priority: 700
# EOF
#
# # Install chromium and chromium-driver
# apt-get update
# apt-get install chromium chromium-driver
#
# # Install selenium
# pip install selenium
# Out:
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# Executing: /tmp/apt-key-gpghome.sEdR1hHyIm/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys DCC9EFBF77E11517
# gpg: key DCC9EFBF77E11517: "Debian Stable Release Key (10/buster) <debian-release@lists.debian.org>" not changed
# gpg: Total number processed: 1
# gpg:              unchanged: 1
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# Executing: /tmp/apt-key-gpghome.dm7xWnX7QD/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 648ACFD622F3D138
# gpg: key DC30D7C23CBBABEE: "Debian Archive Automatic Signing Key (10/buster) <ftpmaster@debian.org>" not changed
# gpg: Total number processed: 1
# gpg:              unchanged: 1
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# Executing: /tmp/apt-key-gpghome.DTETdAkfo7/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 112695A0E562B32A
# gpg: key 4DFAB270CAA96DFA: "Debian Security Archive Automatic Signing Key (10/buster) <ftpmaster@debian.org>" not changed
# gpg: Total number processed: 1
# gpg:              unchanged: 1
# gpg: cannot open '/dev/tty': No such device or address
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# gpg: [stdout]: write error: Broken pipe
# gpg: filter_flush failed on close: Broken pipe
# gpg: cannot open '/dev/tty': No such device or address
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# gpg: [stdout]: write error: Broken pipe
# gpg: filter_flush failed on close: Broken pipe
# gpg: cannot open '/dev/tty': No such device or address
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# gpg: [stdout]: write error: Broken pipe
# gpg: filter_flush failed on close: Broken pipe
# Hit:1 http://deb.debian.org/debian buster InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://deb.debian.org/debian buster-updates InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://deb.debian.org/debian-security buster/updates InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# chromium is already the newest version (90.0.4430.212-1~deb10u1).
# chromium-driver is already the newest version (90.0.4430.212-1~deb10u1).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.
# Requirement already satisfied: selenium in /usr/local/lib/python3.10/dist-packages (4.14.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
#環境変数設定
GET_START_PAGE = 1
GET_NUM = 200
TARGET_URL = f'https://tribeau.jp/surgery_sites/1/case_reports?page={GET_START_PAGE}'

DRIVER_WAIT_TIME = 5

# 各種ファイル保存先
SUBMIT_FILE_PATH =f'/content/drive/MyDrive/Colab Notebooks/dev/web_scraping_crownstrategy/accumulated_list_tribeau_eye_{GET_START_PAGE}.xlsx'

#取得データ格納先
result_dict = {
    '施術名':[],
    'クリニック名': [],
    'クリニック住所': [],
    'URL':[],
    'ドクター名': [],
    'メニュー名':[],
    '費用': [],
    '副作用・リスク': [],
    '患者属性': [],
    '症例画像':[],
}

# %%
#標準ライブラリ
import os
import math
import json

#サードパーティライブラリ
import pandas as pd
from google.colab import drive
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from logging import (
    getLogger,
    StreamHandler,
    DEBUG,
    INFO,
    Formatter,
    config
)
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
options = Options()
options.add_argument('--no-sandbox')
options.add_argument('--headless')
options.add_argument('--disable-gpu')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--ignore-certificate-errors')
options.add_argument("--disable-extensions")
options.add_argument("--disable-popup-blocking")
options.add_argument(
       "user-agent=Mozilla/5.0 (X11; Linux x86_64; rv:93.0) Gecko/20100101 Firefox/93.0"
    )
options.add_experimental_option("prefs", {
    "profile.managed_default_content_settings.images": 2,  # 画像の無効化
    "profile.managed_default_content_settings.plugins": 2,  # プラグインの無効化
})

driver = webdriver.Chrome(options=options)
driver.implicitly_wait(DRIVER_WAIT_TIME)

# %%
#カスタムロガーの設定
with open('/content/drive/MyDrive/Colab Notebooks/dev/web_scraping_crownstrategy/logging_config.json', 'r') as f:
    logger_config = json.load(f)
config.dictConfig(logger_config)
logger = getLogger('main')

try:
      driver.get(TARGET_URL)
      logger.debug(f'{TARGET_URL}：トップページへ移動しました')
except Exception as e:
      logger.error(f'{TARGET_URL}：トップページへ移動出来ませんでした: [e]')
      raise
# Out:
# 2023-10-21 02:55:33,981 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=1：トップページへ移動しました

# %%
#全ページ数を導出
ul_element = driver.find_element(By.CSS_SELECTOR,"[class='Pagination__List-sc-j1ricz-0 hUIXWn']")
li_elements = ul_element.find_elements(By.CSS_SELECTOR,"[class='PageButton__ListItem-sc-5gweb2-1 dbVcqs']")
num_all_pages = int(li_elements[-1].text)

# %%
#一覧ページより詳細ページのリンク先取得
page_num = GET_START_PAGE
end_num = num_all_pages
# end_num = GET_START_PAGE + GET_NUM
target_url = TARGET_URL
detail_url_all = []
retry_count = 0
max_retry = 5

def get_detail_page():
  try:
    ul_element = driver.find_element(By.CSS_SELECTOR,"ul.flex.flex-col.gap-5")
    a_elements = ul_element.find_elements(By.TAG_NAME, "a")
    #詳細ページのリンク先を取得
    detail_urls = [a_element.get_attribute('href') for a_element in a_elements]
    return detail_urls
  except StaleElementReferenceException:
    return get_detail_page()
  except Exception as e:
    logger.error(f'{target_url}:{target_url}の詳細ページリンク取得に失敗しました: [{e}]')

while page_num <= end_num:
  try:
    driver.get(target_url)
    logger.debug(f'{target_url}：一覧ページ{page_num}へ移動しました')
  except Exception as e:
    logger.error(f'{target_url}：一覧ページへ移動出来ませんでした: [e]')
    raise
  # 詳細ページ取得
  detail_urls = get_detail_page()
  detail_url_all.extend(detail_urls)
  logger.debug(detail_urls)

  #次の一覧ページへの遷移先更新
  page_num += 1
  target_url = f'https://tribeau.jp/surgery_sites/1/case_reports?page={page_num}'

print(detail_url_all)
# Out:
# 2023-10-21 02:55:37,204 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=1：一覧ページ1へ移動しました
# 2023-10-21 02:55:38,820 [DEBUG] main: ['https://tribeau.jp/case_reports/31798', 'https://tribeau.jp/case_reports/14731', 'https://tribeau.jp/case_reports/14286', 'https://tribeau.jp/case_reports/31356', 'https://tribeau.jp/case_reports/31627', 'https://tribeau.jp/case_reports/31454', 'https://tribeau.jp/case_reports/31834', 'https://tribeau.jp/case_reports/14878', 'https://tribeau.jp/case_reports/31642', 'https://tribeau.jp/case_reports/14732', 'https://tribeau.jp/case_reports/31291', 'https://tribeau.jp/case_reports/31032', 'https://tribeau.jp/case_reports/14877', 'https://tribeau.jp/case_reports/12899', 'https://tribeau.jp/case_reports/12894', 'https://tribeau.jp/case_reports/12898', 'https://tribeau.jp/case_reports/12942', 'https://tribeau.jp/case_reports/12943', 'https://tribeau.jp/case_reports/27436', 'https://tribeau.jp/case_reports/13991']
# 2023-10-21 02:55:40,564 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=2：一覧ページ2へ移動しました
# 2023-10-21 02:55:42,946 [DEBUG] main: ['https://tribeau.jp/case_reports/31871', 'https://tribeau.jp/case_reports/31867', 'https://tribeau.jp/case_reports/31823', 'https://tribeau.jp/case_reports/31798', 'https://tribeau.jp/case_reports/14731', 'https://tribeau.jp/case_reports/14286', 'https://tribeau.jp/case_reports/31627', 'https://tribeau.jp/case_reports/31454', 'https://tribeau.jp/case_reports/31834', 'https://tribeau.jp/case_reports/31642', 'https://tribeau.jp/case_reports/14877', 'https://tribeau.jp/case_reports/12942', 'https://tribeau.jp/case_reports/31855', 'https://tribeau.jp/case_reports/31854', 'https://tribeau.jp/case_reports/31853', 'https://tribeau.jp/case_reports/31852', 'https://tribeau.jp/case_reports/31851', 'https://tribeau.jp/case_reports/31850', 'https://tribeau.jp/case_reports/31849', 'https://tribeau.jp/case_reports/28489']
# 2023-10-21 02:55:45,095 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page
[DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=20：一覧ページ20へ移動しました
# 2023-10-21 02:56:35,886 [DEBUG] main: ['https://tribeau.jp/case_reports/30787', 'https://tribeau.jp/case_reports/30785', 'https://tribeau.jp/case_reports/30777', 'https://tribeau.jp/case_reports/30776', 'https://tribeau.jp/case_reports/30666', 'https://tribeau.jp/case_reports/30667', 'https://tribeau.jp/case_reports/30767', 'https://tribeau.jp/case_reports/30753', 'https://tribeau.jp/case_reports/30752', 'https://tribeau.jp/case_reports/30735', 'https://tribeau.jp/case_reports/30734', 'https://tribeau.jp/case_reports/30733', 'https://tribeau.jp/case_reports/30732', 'https://tribeau.jp/case_reports/30731', 'https://tribeau.jp/case_reports/30730', 'https://tribeau.jp/case_reports/30728', 'https://tribeau.jp/case_reports/30726', 'https://tribeau.jp/case_reports/30676', 'https://tribeau.jp/case_reports/30674', 'https://tribeau.jp/case_reports/30673']
# 2023-10-21 02:56:37,036 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=21：一覧ページ21へ移動しました
# 2023-10-21 02:56:38,470 [DEBUG] main: ['https://tribeau.jp/case_reports/30766', 'https://tribeau.jp/case_reports/30258', 'https://tribeau.jp/case_reports/30607', 'https://tribeau.jp/case_reports/30749', 'https://tribeau.jp/case_reports/30743', 'https://tribeau.jp/case_reports/30742', 'https://tribeau.jp/case_reports/30367', 'https://tribeau.jp/case_reports/30708', 'https://tribeau.jp/case_reports/30707', 'https://tribeau.jp/case_reports/30706', 'https://tribeau.jp/case_reports/30705', 'https://tribeau.jp/case_reports/30704', 'https://tribeau.jp/case_reports/30703', 'https://tribeau.jp/case_reports/30702', 'https://tribeau.jp/case_reports/30700', 'https://tribeau.jp/case_reports/30699', 'https://tribeau.jp/case_reports/30697', 'https://tribeau.jp/case_reports/30695', 'https://tribeau.jp/case_reports/30691', 'https://tribeau.jp/case_reports/30688']
# 2023-10-21 02:56:39,152 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=22：一覧ページ22へ移動しました
# 2023-10-21 02:56:41,305 [DEBUG] main: ['https://tribeau.jp/case_reports/30686', 'https://tribeau.jp/case_reports/9810', 'https://tribeau.jp/case_reports/30660', 'https://tribeau.jp/case_reports/29204', 'https://tribeau.jp/case_reports/30659', 'https://tribeau.jp/case_reports/30644', 'https://tribeau.jp/case_reports/30643', 'https://tribeau.jp/case_reports/30641', 'https://tribeau.jp/case_reports/30638', 'https://tribeau.jp/case_reports/30637', 'https://tribeau.jp/case_reports/30636', 'https://tribeau.jp/case_reports/30635', 'https://tribeau.jp/case_reports/30628', 'https://tribeau.jp/case_reports/30627', 'https://tribeau.jp/case_reports/30626', 'https://tribeau.jp/case_reports/30625', 'https://tribeau.jp/case_reports/30509', 'https://tribeau.jp/case_reports/30621', 'https://tribeau.jp/case_reports/30619', 'https://tribeau.jp/case_reports/30618']
# 2023-10-21 02:56:42,280 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=23：一覧ページ23へ移動しました
# 2023-10-21 02:56:43,817 [DEBUG] main: ['https://tribeau.jp/case_reports/30615', 'https://tribeau.jp/case_reports/30614', 'https://tribeau.jp/case_reports/30613', 'https://tribeau.jp/case_reports/30609', 'https://tribeau.jp/case_reports/30608', 'https://tribeau.jp/case_reports/30606', 'https://tribeau.jp/case_reports/30605', 'https://tribeau.jp/case_reports/30603', 'https://tribeau.j
[DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=27：一覧ページ27へ移動しました
# 2023-10-21 02:56:54,643 [DEBUG] main: ['https://tribeau.jp/case_reports/30314', 'https://tribeau.jp/case_reports/30304', 'https://tribeau.jp/case_reports/30299', 'https://tribeau.jp/case_reports/30298', 'https://tribeau.jp/case_reports/30297', 'https://tribeau.jp/case_reports/30296', 'https://tribeau.jp/case_reports/30295', 'https://tribeau.jp/case_reports/30294', 'https://tribeau.jp/case_reports/30291', 'https://tribeau.jp/case_reports/30290', 'https://tribeau.jp/case_reports/30287', 'https://tribeau.jp/case_reports/30285', 'https://tribeau.jp/case_reports/30284', 'https://tribeau.jp/case_reports/30279', 'https://tribeau.jp/case_reports/30278', 'https://tribeau.jp/case_reports/30275', 'https://tribeau.jp/case_reports/30271', 'https://tribeau.jp/case_reports/30269', 'https://tribeau.jp/case_reports/30266', 'https://tribeau.jp/case_reports/30265']
# 2023-10-21 02:56:56,191 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=28：一覧ページ28へ移動しました
# 2023-10-21 02:56:57,039 [DEBUG] main: ['https://tribeau.jp/case_reports/30262', 'https://tribeau.jp/case_reports/30261', 'https://tribeau.jp/case_reports/30259', 'https://tribeau.jp/case_reports/30256', 'https://tribeau.jp/case_reports/29543', 'https://tribeau.jp/case_reports/30250', 'https://tribeau.jp/case_reports/30249', 'https://tribeau.jp/case_reports/30248', 'https://tribeau.jp/case_reports/30246', 'https://tribeau.jp/case_reports/30244', 'https://tribeau.jp/case_reports/30242', 'https://tribeau.jp/case_reports/30223', 'https://tribeau.jp/case_reports/30221', 'https://tribeau.jp/case_reports/30211', 'https://tribeau.jp/case_reports/30209', 'https://tribeau.jp/case_reports/30203', 'https://tribeau.jp/case_reports/30189', 'https://tribeau.jp/case_reports/30188', 'https://tribeau.jp/case_reports/30182', 'https://tribeau.jp/case_reports/30180']
# 2023-10-21 02:56:58,067 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=29：一覧ページ29へ移動しました
# 2023-10-21 02:56:59,895 [DEBUG] main: ['https://tribeau.jp/case_reports/30166', 'https://tribeau.jp/case_reports/30165', 'https://tribeau.jp/case_reports/30111', 'https://tribeau.jp/case_reports/30132', 'https://tribeau.jp/case_reports/30139', 'https://tribeau.jp/case_reports/30130', 'https://tribeau.jp/case_reports/30129', 'https://tribeau.jp/case_reports/30126', 'https://tribeau.jp/case_reports/30120', 'https://tribeau.jp/case_reports/30119', 'https://tribeau.jp/case_reports/30118', 'https://tribeau.jp/case_reports/30115', 'https://tribeau.jp/case_reports/30114', 'https://tribeau.jp/case_reports/30113', 'https://tribeau.jp/case_reports/30109', 'https://tribeau.jp/case_reports/30108', 'https://tribeau.jp/case_reports/30107', 'https://tribeau.jp/case_reports/30106', 'https://tribeau.jp/case_reports/29542', 'https://tribeau.jp/case_reports/30104']
# 2023-10-21 02:57:01,366 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page
[DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=40：一覧ページ40へ移動しました
# 2023-10-21 02:57:29,542 [DEBUG] main: ['https://tribeau.jp/case_reports/28710', 'https://tribeau.jp/case_reports/28120', 'https://tribeau.jp/case_reports/29318', 'https://tribeau.jp/case_reports/18677', 'https://tribeau.jp/case_reports/29286', 'https://tribeau.jp/case_reports/24833', 'https://tribeau.jp/case_reports/26655', 'https://tribeau.jp/case_reports/26656', 'https://tribeau.jp/case_reports/26660', 'https://tribeau.jp/case_reports/27376', 'https://tribeau.jp/case_reports/27377', 'https://tribeau.jp/case_reports/27987', 'https://tribeau.jp/case_reports/29282', 'https://tribeau.jp/case_reports/29281', 'https://tribeau.jp/case_reports/29280', 'https://tribeau.jp/case_reports/29279', 'https://tribeau.jp/case_reports/29278', 'https://tribeau.jp/case_reports/29275', 'https://tribeau.jp/case_reports/29273', 'https://tribeau.jp/case_reports/21034']
# 2023-10-21 02:57:30,610 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=41：一覧ページ41へ移動しました
# 2023-10-21 02:57:32,203 [DEBUG] main: ['https://tribeau.jp/case_reports/27243', 'https://tribeau.jp/case_reports/27239', 'https://tribeau.jp/case_reports/23992', 'https://tribeau.jp/case_reports/23960', 'https://tribeau.jp/case_reports/29115', 'https://tribeau.jp/case_reports/29261', 'https://tribeau.jp/case_reports/29240', 'https://tribeau.jp/case_reports/29241', 'https://tribeau.jp/case_reports/26651', 'https://tribeau.jp/case_reports/29225', 'https://tribeau.jp/case_reports/29220', 'https://tribeau.jp/case_reports/29219', 'https://tribeau.jp/case_reports/23964', 'https://tribeau.jp/case_reports/23967', 'https://tribeau.jp/case_reports/28118', 'https://tribeau.jp/case_reports/25782', 'https://tribeau.jp/case_reports/25779', 'https://tribeau.jp/case_reports/27242', 'https://tribeau.jp/case_reports/26366', 'https://tribeau.jp/case_reports/29198']
# 2023-10-21 02:57:33,404 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=42：一覧ページ42へ移動しました
# 2023-10-21 02:57:35,347 [DEBUG] main: ['https://tribeau.jp/case_reports/29196', 'https://tribeau.jp/case_reports/26658', 'https://tribeau.jp/case_reports/29170', 'https://tribeau.jp/case_reports/29168', 'https://tribeau.jp/case_reports/28500', 'https://tribeau.jp/case_reports/28499', 'https://tribeau.jp/case_reports/28498', 'https://tribeau.jp/case_reports/28497', 'https://tribeau.jp/case_reports/24016', 'https://tribeau.jp/case_reports/24017', 'https://tribeau.jp/case_reports/28759', 'https://tribeau.jp/case_reports/28761', 'https://tribeau.jp/case_reports/29136', 'https://tribeau.jp/case_reports/29132', 'https://tribeau.jp/case_reports/15300', 'https://tribeau.jp/case_reports/8796', 'https://tribeau.jp/case_reports/11274', 'https://tribeau.jp/case_reports/7847', 'https://tribeau.jp/case_reports/8118', 'https://tribeau.jp/case_reports/7724']
# 2023-10-21 02:57:36,872 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=43：一覧ページ43へ移動しました
# 2023-10-21 02:57:37,933 [DEBUG] main: ['https://tribeau.jp/case_reports/8253', 'https://tribeau.jp/case_reports/28115', 'https://tribeau.jp/case_reports/27051', 'https://tribeau.jp/case_reports/29110', 'https://tribeau.jp/case_reports/25626', 'https://tribeau.jp/case_reports/25780', 'https://tribeau.jp/case_reports/24765', 'https://tribeau.jp/case_reports/29099', 'https://tribeau.jp/case_reports/29098', 'https://tribeau.jp/case_reports/29065', 'https://tribeau.jp/case_reports/29063', 'https://tribeau.jp/case_reports/29044', 'https://tribeau.jp/case_reports/29023', 'https://tribeau.jp/case_reports/29021', 'https://tribeau.jp/case_reports/29020', 'https://tribeau.jp/case_reports/25781', 'https://tribeau.jp/case_reports/28840', 'https://tribeau.jp/case_reports/29011', 'https://tribeau.jp/case_reports/29010', 'https://tribeau.jp/case_reports/29009']
# 2023-10-21 02:57:39,339 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=44：一覧ページ44へ移動しました
# 2023-10-21 02:57:40,321 [DEBUG] main: ['https://tribeau.jp/case_reports/28997', 'https://tribeau.jp/case_reports/28986', 'https://tribeau.jp/case_reports/28983', 'https://tribeau.jp/case_reports/28111', 'https://tribeau.jp/case_reports/25625', 'https://tribeau.jp/case_reports/28968', 'https://tribeau.jp/case_reports/28967', 'https://tribeau.jp/case_reports/28960', 'https://tribeau.jp/case_reports/28956', 'https://tribeau.jp/case_reports/28952', 'https://tribeau.jp/case_reports/28940', 'https://tribeau.jp/case_reports/28939', 'https://tribeau.jp/case_reports/28932', 'https://tribeau.jp/case_reports/26801', 'https://tribeau.jp/case_reports/28198', 'https://tribeau.jp/case_reports/28196', 'https://tribeau.jp/case_reports/28918', 'https://tribeau.jp/case_reports/28917', 'https://tribeau.jp/case_reports/28915', 'https://tribeau.jp/case_reports/28912']
# 2023-10-21 02:57:41,819 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=45：一覧ページ45へ移動しました
# 2023-10-21 02:57:42,736 [DEBUG] main: ['https://tribeau.jp/case_reports/28910', 'https://tribeau.jp/case_reports/28907', 'https://tribeau.jp/case_reports/28906', 'https://tribeau.jp/case_reports/28905', 'https://tribeau.jp/case_reports/27902', 'https://tribeau.jp/case_reports/28902', 'https://tribeau.jp/case_reports/24096', 'https://tribeau.jp/case_reports/28897', 'https://tribeau.jp/case_reports/28624', 'https://tribeau.jp/case_reports/28614', 'https://tribeau.jp/case_reports/28848', 'https://tribeau.jp/case_reports/28847', 'https://tribeau.jp/case_reports/28845', 'https://tribeau.jp/case_reports/28844', 'https://tribeau.jp/case_reports/28843', 'https://tribeau.jp/case_reports/28709', 'https://tribeau.jp/case_reports/28838', 'https://tribeau.jp/case_reports/28830', 'https://tribeau.jp/case_reports/28829', 'https://tribeau.jp/case_reports/28828']
# 2023-10-21 02:57:44,146 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=46：一覧ページ46へ移動しました
# 2023-10-21 02:57:44,899 [DEBUG] main: ['https://tribeau.jp/case_reports/28827', 'https://tribeau.jp/case_reports/28826', 'https://tribeau.jp/case_reports/28825', 'https://tribeau.jp/case_reports/28824', 'https://tribeau.jp/case_reports/28823', 'https://tribeau.jp/case_reports/28819', 'https://tribeau.jp/case_reports/28818', 'https://tribeau.jp/case_reports/28816', 'https://tribeau.jp/case_reports/28815', 'https://tribeau.jp/case_reports/28812', 'https://tribeau.jp/case_reports/28811', 'https://tribeau.jp/case_reports/28808', 'https://tribeau.jp/case_reports/28807', 'https://tribeau.jp/case_reports/28805', 'https://tribeau.jp/case_reports/28795', 'https://tribeau.jp/case_reports/28793', 'https://tribeau.jp/case_reports/28785', 'https://tribeau.jp/case_reports/28777', 'https://tribeau.jp/case_reports/28772', 'https://tribeau.jp/case_reports/28762']
# 2023-10-21 02:57:45,951 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=47：一覧ページ47へ移動しました
# 2023-10-21 02:57:48,079 [DEBUG] main: ['https://tribeau.jp/case_reports/10514', 'https://tribeau.jp/case_reports/8504', 'https://tribeau.jp/case_reports/8255', 'https://tribeau.jp/case_reports/28747', 'https://tribeau.jp/case_reports/28734', 'https://tribeau.jp/case_reports/28733', 'https://tribeau.jp/case_reports/28731', 'https://tribeau.jp/case_reports/28729', 'https://tribeau.jp/case_reports/28721', 'https://tribeau.jp/case_reports/28718', 'https://tribeau.jp/case_reports/27875', 'https://tribeau.jp/case_reports/28705', 'https://tribeau.jp/case_reports/28703', 'https://tribeau.jp/case_reports/28700', 'https://tribeau.jp/case_reports/28698', 'https://tribeau.jp/case_reports/28697', 'https://tribeau.jp/case_reports/28696', 'https://tribeau.jp/case_reports/28695', 'https://tribeau.jp/case_reports/28692', 'https://tribeau.jp/case_reports/28690']
# 2023-10-21 02:57:49,050 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=48：一覧ページ48へ移動しました
# 2023-10-21 02:57:50,303 [DEBUG] main: ['https://tribeau.jp/case_reports/28671', 'https://tribeau.jp/case_reports/28665', 'https://tribeau.jp/case_reports/28663', 'https://tribeau.jp/case_reports/28657', 'https://tribeau.jp/case_reports/28656', 'https://tribeau.jp/case_reports/28655', 'https://tribeau.jp/case_reports/28654', 'https://tribeau.jp/case_reports/28653', 'https://tribeau.jp/case_reports/28649', 'https://tribeau.jp/case_reports/25792', 'https://tribeau.jp/case_reports/28638', 'https://tribeau.jp/case_reports/28637', 'https://tribeau.jp/case_reports/28635', 'https://tribeau.jp/case_reports/28631', 'https://tribeau.jp/case_reports/28626', 'https://tribeau.jp/case_reports/28621', 'https://tribeau.jp/case_reports/28619', 'https://tribeau.jp/case_reports/28615', 'https://tribeau.jp/case_reports/28610', 'https://tribeau.jp/case_reports/28607']
# 2023-10-21 02:57:51,314 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=49：一覧ページ49へ移動しました
# 2023-10-21 02:57:52,545 [DEBUG] main: ['https://tribeau.jp/case_reports/28606', 'https://tribeau.jp/case_reports/28600', 'https://tribeau.jp/case_reports/28495', 'https://tribeau.jp/case_reports/28494', 'https://tribeau.jp/case_reports/28493', 'https://tribeau.jp/case_reports/28492', 'https://tribeau.jp/case_reports/28594', 'https://tribeau.jp/case_reports/28591', 'https://tribeau.jp/case_reports/28590', 'https://tribeau.jp/case_reports/28588', 'https://tribeau.jp/case_reports/28587', 'https://tribeau.jp/case_reports/28583', 'https://tribeau.jp/case_reports/26894', 'https://tribeau.jp/case_reports/28576', 'https://tribeau.jp/case_reports/27017', 'https://tribeau.jp/case_reports/28560', 'https://tribeau.jp/case_reports/28557', 'https://tribeau.jp/case_reports/28554', 'https://tribeau.jp/case_reports/28553', 'https://tribeau.jp/case_reports/28535']
# 2023-10-21 02:57:53,484 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=50：一覧ページ50へ移動しました
# ...
# 2023-10-21 03:05:20,085 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=222：一覧ページ222へ移動しました
# 2023-10-21 03:05:21,006 [DEBUG] main: ['https://tribeau.jp/case_reports/16879', 'https://tribeau.jp/case_reports/16878', 'https://tribeau.jp/case_reports/16877', 'https://tribeau.jp/case_reports/16876', 'https://tribeau.jp/case_reports/16873', 'https://tribeau.jp/case_reports/16872', 'https://tribeau.jp/case_reports/16870', 'https://tribeau.jp/case_reports/16867', 'https://tribeau.jp/case_reports/16865', 'https://tribeau.jp/case_reports/16864', 'https://tribeau.jp/case_reports/16861', 'https://tribeau.jp/case_reports/16860', 'https://tribeau.jp/case_reports/16859', 'https://tribeau.jp/case_reports/16857', 'https://tribeau.jp/case_reports/16844', 'https://tribeau.jp/case_reports/16843', 'https://tribeau.jp/case_reports/16832', 'https://tribeau.jp/case_reports/16842', 'https://tribeau.jp/case_reports/16841', 'https://tribeau.jp/case_reports/16840']
# 2023-10-21 03:05:22,617 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=223：一覧ページ223へ移動しました
# 2023-10-21 03:05:23,439 [DEBUG] main: ['https://tribeau.jp/case_reports/16839', 'https://tribeau.jp/case_reports/16838', 'https://tribeau.jp/case_reports/16827', 'https://tribeau.jp/case_reports/16825', 'https://tribeau.jp/case_reports/16823', 'https://tribeau.jp/case_reports/16819', 'https://tribeau.jp/case_reports/16818', 'https://tribeau.jp/case_reports/16817', 'https://tribeau.jp/case_reports/16816', 'https://tribeau.jp/case_reports/16815', 'https://tribeau.jp/case_reports/16814', 'https://tribeau.jp/case_reports/16813', 'https://tribeau.jp/case_reports/16811', 'https://tribeau.jp/case_reports/16794', 'https://tribeau.jp/case_reports/16784', 'https://tribeau.jp/case_reports/16778', 'https://tribeau.jp/case_reports/16777', 'https://tribeau.jp/case_reports/16776', 'https://tribeau.jp/case_reports/16768', 'https://tribeau.jp/case_reports/16773']
# 2023-10-21 03:05:24,384 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=224：一覧ページ224へ移動しました
# 2023-10-21 03:05:25,830 [DEBUG] main: ['https://tribeau.jp/case_reports/16771', 'https://tribeau.jp/case_reports/16767', 'https://tribeau.jp/case_reports/16766', 'https://tribeau.jp/case_reports/16764', 'https://tribeau.jp/case_reports/16752', 'https://tribeau.jp/case_reports/16751', 'https://tribeau.jp/case_reports/16750', 'https://tribeau.jp/case_reports/16749', 'https://tribeau.jp/case_reports/16748', 'https://tribeau.jp/case_reports/16738', 'https://tribeau.jp/case_reports/16734', 'https://tribeau.jp/case_reports/16732', 'https://tribeau.jp/case_reports/16728', 'https://tribeau.jp/case_reports/16727', 'https://tribeau.jp/case_reports/16726', 'https://tribeau.jp/case_reports/16724', 'https://tribeau.jp/case_reports/16721', 'https://tribeau.jp/case_reports/16720', 'https://tribeau.jp/case_reports/16528', 'https://tribeau.jp/case_reports/16715']
# 2023-10-21 03:05:26,809 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=225：一覧ページ225へ移動しました
# 2023-10-21 03:05:28,423 [DEBUG] main: ['https://tribeau.jp/case_reports/16714', 'https://tribeau.jp/case_reports/16706', 'https://tribeau.jp/case_reports/16705', 'https://tribeau.jp/case_reports/16704', 'https://tribeau.jp/case_reports/16703', 'https://tribeau.jp/case_reports/16702', 'https://tribeau.jp/case_reports/16701', 'https://tribeau.jp/case_reports/16700', 'https://tribeau.jp/case_reports/16699', 'https://tribeau.jp/case_reports/16698', 'https://tribeau.jp/case_reports/16697', 'https://tribeau.jp/case_reports/16696', 'https://tribeau.jp/case_reports/16695', 'https://tribeau.jp/case_reports/16694', 'https://tribeau.jp/case_reports/16693', 'https://tribeau.jp/case_reports/16692', 'https://tribeau.jp/case_reports/16691', 'https://tribeau.jp/case_reports/16690', 'https://tribeau.jp/case_reports/16689', 'https://tribeau.jp/case_reports/16688']
# 2023-10-21 03:05:30,181 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=226：一覧ページ226へ移動しました
# 2023-10-21 03:05:34,400 [DEBUG] main: ['https://tribeau.jp/case_reports/16687', 'https://tribeau.jp/case_reports/16686', 'https://tribeau.jp/case_reports/16685', 'https://tribeau.jp/case_reports/16684', 'https://tribeau.jp/case_reports/16683', 'https://tribeau.jp/case_reports/16682', 'https://tribeau.jp/case_reports/16681', 'https://tribeau.jp/case_reports/16680', 'https://tribeau.jp/case_reports/16679', 'https://tribeau.jp/case_reports/16678', 'https://tribeau.jp/case_reports/16675', 'https://tribeau.jp/case_reports/16670', 'https://tribeau.jp/case_reports/16668', 'https://tribeau.jp/case_reports/16665', 'https://tribeau.jp/case_reports/16643', 'https://tribeau.jp/case_reports/16647', 'https://tribeau.jp/case_reports/16648', 'https://tribeau.jp/case_reports/16649', 'https://tribeau.jp/case_reports/16650', 'https://tribeau.jp/case_reports/16652']
# 2023-10-21 03:05:35,091 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=227：一覧ページ227へ移動しました
# 2023-10-21 03:05:37,133 [DEBUG] main: ['https://tribeau.jp/case_reports/16657', 'https://tribeau.jp/case_reports/16660', 'https://tribeau.jp/case_reports/16654', 'https://tribeau.jp/case_reports/16653', 'https://tribeau.jp/case_reports/16641', 'https://tribeau.jp/case_reports/16640', 'https://tribeau.jp/case_reports/16638', 'https://tribeau.jp/case_reports/16634', 'https://tribeau.jp/case_reports/16628', 'https://tribeau.jp/case_reports/16618', 'https://tribeau.jp/case_reports/16610', 'https://tribeau.jp/case_reports/16608', 'https://tribeau.jp/case_reports/16607', 'https://tribeau.jp/case_reports/16590', 'https://tribeau.jp/case_reports/16572', 'https://tribeau.jp/case_reports/16571', 'https://tribeau.jp/case_reports/16570', 'https://tribeau.jp/case_reports/16542', 'https://tribeau.jp/case_reports/16534', 'https://tribeau.jp/case_reports/16529']
# 2023-10-21 03:05:38,201 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=228：一覧ページ228へ移動しました
# 2023-10-21 03:05:39,532 [DEBUG] main: ['https://tribeau.jp/case_reports/16524', 'https://tribeau.jp/case_reports/16523', 'https://tribeau.jp/case_reports/16520', 'https://tribeau.jp/case_reports/16516', 'https://tribeau.jp/case_reports/16503', 'https://tribeau.jp/case_reports/16493', 'https://tribeau.jp/case_reports/16492', 'https://tribeau.jp/case_reports/16460', 'https://tribeau.jp/case_reports/16487', 'https://tribeau.jp/case_reports/16485', 'https://tribeau.jp/case_reports/16483', 'https://tribeau.jp/case_reports/16482', 'https://tribeau.jp/case_reports/16481', 'https://tribeau.jp/case_reports/16462', 'https://tribeau.jp/case_reports/16457', 'https://tribeau.jp/case_reports/16449', 'https://tribeau.jp/case_reports/16446', 'https://tribeau.jp/case_reports/16445', 'https://tribeau.jp/case_reports/16441', 'https://tribeau.jp/case_reports/16439']
# 2023-10-21 03:05:40,974 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=229：一覧ページ229へ移動しました
# 2023-10-21 03:05:42,175 [DEBUG] main: ['https://tribeau.jp/case_reports/16438', 'https://tribeau.jp/case_reports/16435', 'https://tribeau.jp/case_reports/16433', 'https://tribeau.jp/case_reports/16431', 'https://tribeau.jp/case_reports/16429', 'https://tribeau.jp/case_reports/16427', 'https://tribeau.jp/case_reports/16425', 'https://tribeau.jp/case_reports/16423', 'https://tribeau.jp/case_reports/16422', 'https://tribeau.jp/case_reports/16421', 'https://tribeau.jp/case_reports/16420', 'https://tribeau.jp/case_reports/16419', 'https://tribeau.jp/case_reports/16418', 'https://tribeau.jp/case_reports/16417', 'https://tribeau.jp/case_reports/16415', 'https://tribeau.jp/case_reports/16414', 'https://tribeau.jp/case_reports/16413', 'https://tribeau.jp/case_reports/16412', 'https://tribeau.jp/case_reports/16411', 'https://tribeau.jp/case_reports/16410']
# 2023-10-21 03:05:43,271 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=230：一覧ページ230へ移動しました
# 2023-10-21 03:05:44,775 [DEBUG] main: ['https://tribeau.jp/case_reports/16409', 'https://tribeau.jp/case_reports/16407', 'https://tribeau.jp/case_reports/16406', 'https://tribeau.jp/case_reports/16405', 'https://tribeau.jp/case_reports/16402', 'https://tribeau.jp/case_reports/16401', 'https://tribeau.jp/case_reports/16397', 'https://tribeau.jp/case_reports/16394', 'https://tribeau.jp/case_reports/16390', 'https://tribeau.jp/case_reports/16389', 'https://tribeau.jp/case_reports/16381', 'https://tribeau.jp/case_reports/16371', 'https://tribeau.jp/case_reports/16369', 'https://tribeau.jp/case_reports/16365', 'https://tribeau.jp/case_reports/16339', 'https://tribeau.jp/case_reports/16334', 'https://tribeau.jp/case_reports/16332', 'https://tribeau.jp/case_reports/16331', 'https://tribeau.jp/case_reports/16330', 'https://tribeau.jp/case_reports/16325']
# 2023-10-21 03:05:46,560 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=231：一覧ページ231へ移動しました
# 2023-10-21 03:05:47,816 [DEBUG] main: ['https://tribeau.jp/case_reports/16321', 'https://tribeau.jp/case_reports/16315', 'https://tribeau.jp/case_reports/16308', 'https://tribeau.jp/case_reports/16305', 'https://tribeau.jp/case_reports/16292', 'https://tribeau.jp/case_reports/16282', 'https://tribeau.jp/case_reports/16281', 'https://tribeau.jp/case_reports/16265', 'https://tribeau.jp/case_reports/16264', 'https://tribeau.jp/case_reports/16263', 'https://tribeau.jp/case_reports/16259', 'https://tribeau.jp/case_reports/16257', 'https://tribeau.jp/case_reports/16254', 'https://tribeau.jp/case_reports/16251', 'https://tribeau.jp/case_reports/16187', 'https://tribeau.jp/case_reports/16248', 'https://tribeau.jp/case_reports/16247', 'https://tribeau.jp/case_reports/16245', 'https://tribeau.jp/case_reports/16244', 'https://tribeau.jp/case_reports/16243']
# 2023-10-21 03:05:48,799 [DEBUG] main: https://tribeau.jp/surgery_sites/1/case_reports?page=232：一覧ページ232へ移動しました
# 2023-10-21 03:05:50,502 [DEBUG] main: ['https://tribeau.jp/case_reports/16241', 'https://tribeau.jp/case_reports/16239', 'https://tribeau.jp/case_reports/16236', 'https://tribeau.jp/case_reports/16232', 'https://tribeau.jp/case_reports/16228', 'https://tribeau.jp/case_reports/16230', 'https://tribeau.jp/case_reports/16223', 'https://tribeau.jp/case_reports/16196', 'https://tribeau.jp/case_reports/16195', 'https://tribeau.jp/case_reports/16193', 'https://tribeau.jp/case_reports/16192', 'https://tribeau.jp/case_reports/16191', 'https://tribeau.jp/case_reports/16190', 'https://tribeau.jp/case_reports/15837', 'https://tribeau.jp/case_reports/16182', 'https://tribeau.jp/case_reports/16181', 'https://tribeau.jp/case_reports/16179', 'https://tribeau.jp/case_reports/16176', 'https://tribeau.jp/case_reports/16172', 'https://tribeau.jp/case_reports/16169']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-153-8b8e3fec9bd7> in <cell line: 22>()
#      22 while page_num <= end_num:
#      23   try:
# ---> 24     driver.get(target_url)
#      25     logger.debug(f'{target_url}：一覧ページ{page_num}へ移動しました')
#      26   except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     351     def get(self, url: str) -> None:
#     352         """Loads a web page in the current browser session."""
# --> 353         self.execute(Command.GET, {"url": url})
#     354
#     355     @property
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     340                 params["sessionId"] = self.session_id
#     341
# --> 342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
#     344             self.error_handler.check_response(response)
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     295         data = utils.dump_json(params)
#     296         url = f"{self._url}{path}"
# --> 297         return self._request(command_info[0], url, body=data)
#     298
#     299     def _request(self, method, url, body=None):
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     316
#     317         if self.keep_alive:
# --> 318             response = self._conn.request(method, url, body=body, headers=headers)
#     319             statuscode = response.status
#     320         else:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/_request_methods.py in request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     116             )
#     117         else:
# --> 118             return self.request_encode_body(
#     119                 method, url, fields=fields, headers=headers, **urlopen_kw
#     120             )
#
# /usr/local/lib/python3.10/dist-packages/urllib3/_request_methods.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     215         extra_kw.update(urlopen_kw)
#     216
# --> 217         return self.urlopen(method, url, **extra_kw)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     441             response = conn.urlopen(method, url, **kw)
#     442         else:
# --> 443             response = conn.urlopen(method, u.request_uri, **kw)
#     444
#     445         redirect_location = redirect and response.get_redirect_location()
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# 詳細ページにて各情報を取得
#クリニック名/施術名/ドクター名/症例画像取得
def get_text_by_selector(selector):
    try:
        text = driver.find_element(By.CSS_SELECTOR, selector).text
    except NoSuchElementException:
        text = ""
    return text

def get_text_by_selector_index(selector, index):
    try:
        text = driver.find_elements(By.CSS_SELECTOR, selector)[index].text
    except (IndexError, NoSuchElementException):
        text = ""
    return text

def save_file_from_dict(result_dict, submit_file_path):
  # URLの最大長さを取得
  max_img_url_all_length = max(len(imgs) for imgs in result_dict['症例画像'])

  # URLを個別のカラムに分ける
  img_columns = {}
  for i in range(max_img_url_all_length):
      img_columns[f'症例画像{i+1}'] = [imgs[i] if i < len(imgs) else '' for imgs in result_dict['症例画像']]

  # data 辞書の更新
  del result_dict['症例画像']
  result_dict.update(img_columns)

  #データフレーム作成
  df_result = pd.DataFrame(result_dict)

  #データ前処理
  df_result_unique = df_result.drop_duplicates(subset='URL', keep='first')
  df_result_cleaned = df_result_unique.dropna(subset=['URL', 'クリニック名'])

  # 提出ファイル用出力
  df_result_cleaned.to_excel(SUBMIT_FILE_PATH, header=True, index=False)

cnt = 0
for detail_url in detail_url_all:
  try:
    driver.get(detail_url)
    logger.debug(f'詳細ページ{detail_url}へ移動しました')
  except Exception as e:
    logger.error(f'詳細ページ{detail_url}へ移動出来ませんでした: [e]')
    continue

  try:
      #施術名/クリニック名/クリニック住所/ドクター名/メニュー名/費用/副作用・リスク/患者属性/症例画像_施術前/症例画像_施術後/URL
      medical_procedure_name = get_text_by_selector("a.py-1\\.5.px-3.rounded-full.text-primary-high.text-text-tag.font-bold.border.bg-background-main.border-primary-high")
      clinic_name = get_text_by_selector("div.ClinicAndDoctorLink__ClinicName-sc-1s8w7y6-2.ItnDt")
      clinic_address = get_text_by_selector_index("div.ClinicSection__ClinicOneInfo-sc-xpwsv2-5.kQoWQT", 1)
      doctor_name = get_text_by_selector("div.ClinicAndDoctorLink__DoctorName-sc-1s8w7y6-5.knTAKt")
      menu = get_text_by_selector("span.CaseReportPage__CaseReportTitle-sc-1w0k5lc-1.cHMnmm")
      cost = get_text_by_selector_index("div.Treatment__SectionContent-sc-14kahvy-3.dQGJTE", 1)
      side_effect = get_text_by_selector_index("div.Treatment__SectionContent-sc-14kahvy-3.dQGJTE", 2)
      tmp = get_text_by_selector("span.CaseReportPage__CaseReportSubTitle-sc-1w0k5lc-2.jYMLSR")
      if len(tmp) > 0:
        patient_characteristics = tmp.split('/')[1].strip()
      else:
        patient_characteristics = ""

      #画像取得へ遷移
      detail_img_url = f'{detail_url}/images'
      img_url_all = []
      try:
        driver.get(detail_img_url)
        logger.debug(f'詳細ページ{detail_img_url}へ移動しました')
      except Exception as e:
        logger.error(f'詳細ページ{detail_img_url}へ移動出来ませんでした: [e]')
        continue
      div_elements = driver.find_elements(By.CSS_SELECTOR, "div.CaseReportImagePage__Flex-sc-3j6mr5-3.bQVarB")
      for div_element in div_elements:
        img_elements = div_element.find_elements(By.CSS_SELECTOR, "img.CaseReportImagePage__Photo-sc-3j6mr5-6.jXGOqB")
        img_urls = [img_element.get_attribute('src') for img_element in img_elements]
        img_url_all.extend(img_urls)

      #結果格納
      result_dict['施術名'].append(medical_procedure_name)
      result_dict['クリニック名'].append(clinic_name)
      result_dict['クリニック住所'].append(clinic_address)
      result_dict['URL'].append(detail_url)
      result_dict['ドクター名'].append(doctor_name)
      result_dict['メニュー名'].append(menu)
      result_dict['費用'].append(cost)
      result_dict['副作用・リスク'].append(side_effect)
      result_dict['患者属性'].append(patient_characteristics)
      result_dict['症例画像'].append(img_url_all)

      cnt += 1
      logger.debug(f'詳細ページ{detail_url}の取得完了 ■進捗: {cnt}/{len(detail_url_all)}' )

      # 中間生成物作成
      if cnt ==
      save_file_from_dict(result_dict, SUBMIT_FILE_PATH)



  except Exception as e:
      logger.error(f'詳細ページ{detail_url}の取得に失敗しました: [e]')




df_result

# %%
#データ前処理
df_result_unique = df_result.drop_duplicates(subset='URL', keep='first')
df_result_cleaned = df_result_unique.dropna(subset=['URL', 'クリニック名'])

df_result_cleaned

# %%
# 提出ファイル用出力
df_result_cleaned.to_excel(SUBMIT_FILE_PATH, header=True, index=False)
